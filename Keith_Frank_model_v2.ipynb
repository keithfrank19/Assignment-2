# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data.csv')
dataset.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
X= dataset.iloc[:,2:32].values
Y = dataset.iloc[:,1].values

# %%
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
print(X.shape)
# Out:
# (569, 30)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
    classifier = Sequential()
    classifier.add(Dense(units = 16,input_dim = 30, kernel_initializer = 'uniform', activation = 'relu'))
    ##classifier.add(Dropout(p=0.1))
    classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
    ##classifier.add(Dropout(p=0.1))
    classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
    ##classifier.add(Dropout(p=0.1))
    classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
    ##classifier.add(Dropout(p=0.1))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam' ,loss  = 'binary_crossentropy' ,metrics = ['accuracy'])

# %%
classifier.fit(x_train, y_train, batch_size = 30, epochs = 100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 2ms/step - loss: 0.6921 - accuracy: 0.6374
# Epoch 2/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.6374
# Epoch 3/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.6374
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6707 - accuracy: 0.6374
# Epoch 5/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6130 - accuracy: 0.6374
# Epoch 6/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.7385
# Epoch 7/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3405 - accuracy: 0.9495
# Epoch 8/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2561 - accuracy: 0.9670
# Epoch 9/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1772 - accuracy: 0.9736
# Epoch 10/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9758
# Epoch 11/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9758
# Epoch 12/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9758
# Epoch 13/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0728 - accuracy: 0.9824
# Epoch 14/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9824
# Epoch 15/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9846
# Epoch 16/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9868
# Epoch 17/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9868
# Epoch 18/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9890
# Epoch 19/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 0.9868
# Epoch 20/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9890
# Epoch 21/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9890
# Epoch 22/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9890
# Epoch 23/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9890
# Epoch 24/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 0.9890
# Epoch 25/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9890
# Epoch 26/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0477 - accuracy: 0.9890
# Epoch 27/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 0.9890
# Epoch 28/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 0.9890
# Epoch 29/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9912
# Epoch 30/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9912
# Epoch 31/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9912
# Epoch 32/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9912
# Epoch 33/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9912
# Epoch 34/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9912
# Epoch 35/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9912
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9912
# Epoch 37/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9912
# Epoch 38/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9912
# Epoch 39/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9912
# Epoch 40/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 0.9912
# Epoch 41/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 0.9912
# Epoch 42/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9912
# Epoch 43/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9912
# Epoch 44/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9912
# Epoch 45/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9912
# Epoch 46/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9912
# Epoch 47/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9912
# Epoch 48/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9912
# Epoch 49/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9912
# Epoch 50/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9912
# Epoch 51/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9912
# Epoch 52/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9912
# Epoch 53/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9912
# Epoch 54/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9912
# Epoch 55/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9912
# Epoch 56/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9912
# Epoch 57/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9934
# Epoch 58/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9934
# Epoch 59/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9934
# Epoch 60/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.9934
# Epoch 61/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9956
# Epoch 62/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9956
# Epoch 63/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9934
# Epoch 64/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9956
# Epoch 65/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9956
# Epoch 66/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9956
# Epoch 67/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9956
# Epoch 68/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9956
# Epoch 69/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9956
# Epoch 70/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9956
# Epoch 71/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.9956
# Epoch 72/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9956
# Epoch 73/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9956
# Epoch 74/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9956
# Epoch 75/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9956
# Epoch 76/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9956
# Epoch 77/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9956
# Epoch 78/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9934
# Epoch 79/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9956
# Epoch 80/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9956
# Epoch 81/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9956
# Epoch 82/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9956
# Epoch 83/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9956
# Epoch 84/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9956
# Epoch 85/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9956
# Epoch 86/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9978
# Epoch 87/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9978
# Epoch 88/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9978
# Epoch 89/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9978
# Epoch 90/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9978
# Epoch 91/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 92/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 93/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9978
# Epoch 94/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 95/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 96/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 97/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 98/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 99/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 100/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000

# %%
y_pred = classifier.predict(x_test)
y_pred = y_pred > 0.5
from sklearn.metrics import confusion_matrix
confusion_matrix (y_pred, y_test)
# Out:
# array([[67,  3],
#        [ 0, 44]])

# %% [markdown]
# Conclusion - 97% accuracy
